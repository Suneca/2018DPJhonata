# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Jhonata Ferreira de Souza
# ___

# %% [markdown]
# ## Como o nivel de escolaridade dos aldultos influencia a taxa de natalidade de sua região?

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Filtros da base de dados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\jhona\Downloads\Ciencia dos Dados DP\Projeto 1

# %%
#Se usar o arquivo descompactado
#pd.read_csv('PES2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
data_2015 = pd.read_csv('PES2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')
data_2015
# Out:
#         Unnamed: 0  V0101  UF  V0102  V0103  V0301  V0302  V3031  V3032  \
# 0                0   2015  11     15      1      1      2     27      2
# 1                1   2015  11     15      3      1      4      4      5
# 2                2   2015  11     15      4      1      4      4      1
# 3                3   2015  11     15      4      2      2      5      6
# 4                4   2015  11     15      4      3      4      8      4
# 5                5   2015  11     15      4      4      4      1     12
# 6                6   2015  11     15      4      5      4      6     12
# 7                7   2015  11     15      4      6      4      8      9
# 8                8   2015  11     15      5      1      2      3      1
# 9                9   2015  11     15      5      2      4      1      1
# 10              10   2015  11     15      6      1      4      3      6
# 11              11   2015  11     15      7      1      4      8     12
# ...

# %%
cortada = data_2015.loc[:,['UF','V04020','V0404','V4011','V6002','V6003','V0606','V6007','V0611','V1141','V1142','V1151','V1152']]
cortada
# Out:
#         UF  V04020  V0404  V4011  V6002  V6003  V0606  V6007  V0611  V1141  \
# 0       11     NaN      8    0.0    NaN    NaN    2.0    5.0    1.0    NaN
# 1       11     NaN      2    5.0    NaN    NaN    2.0    5.0    1.0    NaN
# 2       11     NaN      8    NaN    4.0    5.0    NaN    NaN    NaN    0.0
# 3       11     NaN      8    NaN    NaN    NaN    2.0    8.0    1.0    NaN
# 4       11     NaN      8    0.0    4.0    1.0    NaN    NaN    NaN    NaN
# 5       11     NaN      8    NaN    2.0    1.0    NaN    NaN    NaN    NaN
# 6       11     NaN      8    NaN    2.0    7.0    NaN    NaN    NaN    NaN
# 7       11     NaN      8    0.0    NaN    NaN    2.0    5.0    1.0    NaN
# 8       11     NaN      2    0.0    NaN    NaN    2.0    4.0    3.0    NaN
# 9       11     NaN      8    7.0    NaN    NaN    2.0    1.0    3.0    1.0
# 10      11     NaN      2    5.0    NaN    NaN    2.0    4.0    3.0    0.0
# ...

# %%
cortada.to_excel("compacto.xlsx", 'Sheet1')

# %% [markdown]
# ___
# ## Análise e Resultados

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
